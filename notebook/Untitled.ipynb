# %%
import pandas as pd
# importing dataset
df = pd.read_csv('car_data.csv')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def recommend_func(data, min_price, max_price, **kwargs):
    '''
    data set: car_data
    parameters: price_range, **kwargs (optional: year, odometer, manufacturer, paint_color, car_type, and additional parameters)
    return: dataframe containing the top similar cars
    '''
    # Apply filters based on provided parameters
    filtered_data = data.copy()  # Make a copy of the original data to avoid modifying it
    for key, value in kwargs.items():
        if value:  # Check if value is provided
            if key == 'year':
                print(value)
                value = value + ' AD'
                print(value)
                filtered_data = filtered_data[filtered_data[key] == value]
            elif key == 'odometer':
                value = value +  ' miles'
                filtered_data = filtered_data[filtered_data[key] == value]
            elif key == 'cylinders':
                value = value + ' cylinders'
                filtered_data = filtered_data[filtered_data[key] == value]
            else:
                filtered_data = filtered_data[filtered_data[key] == value]

    # Filter data based on price_range
    filtered_data = filtered_data[(filtered_data['price'] >= min_price) & (filtered_data['price'] <= max_price)]
    print(filtered_data)
    if kwargs:
        if len(filtered_data) == 0:
            return None  # Return None if no data matches the filters
        
        # Perform similarity calculations based on car details
        tfidf_vectorizer = TfidfVectorizer()
        tfidf_matrix = tfidf_vectorizer.fit_transform(filtered_data['car_details'])
        similarity_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)

        # Get indices of top similar cars
        car_indices = similarity_matrix.argsort()[:, ::-1]  # Exclude self-similarity and get top 5 similar indices

        # Recommendation for top 6 similar cars
        rec = filtered_data.iloc[car_indices.flatten()[1:7]]
    
        return rec
    
    else:
        # Sort cars based on optimal value (e.g., manufacturing year, odometer)
        sorted_cars = filtered_data.sort_values(by=['years', 'odometers'], ascending=[False, True])

        # Return the top 5 cars with the best optimal value
        best_cars = sorted_cars.head(5)
        return best_cars

# %%
column_values = {'year': '2018'}
recommended_cars = recommend_func(df, min_price=12000, max_price=17000, **column_values)
print(recommended_cars)
# Out:
# 2018
# 2018 AD
#        price     year manufacturer      model  condition    cylinders fuel  \
# 666    16500  2018 AD       subaru     legacy  excellent  4 cylinders  gas
# 700    14995  2018 AD       nissan   versa sv   like new  4 cylinders  gas
# 724    15950  2018 AD     chrysler   pacifica  excellent  6 cylinders  gas
# 733    16500  2018 AD       subaru     legacy  excellent  4 cylinders  gas
# 743    14999  2018 AD       nissan   sentra s  excellent  4 cylinders  gas
# ...      ...      ...          ...        ...        ...          ...  ...
# 57564  16700  2018 AD    chevrolet    equinox   like new  4 cylinders  gas
# 57654  15950  2018 AD    chevrolet    equinox   like new  4 cylinders  gas
# 57686  16995  2018 AD         ford  fusion se  excellent  4 cylinders  gas
# 57967  13495  2018 AD       nissan     sentra  excellent  4 cylinders  gas
# 57977  16470  2018 AD    chevrolet    equinox  excellent  4 cylinders  gas
#
#            odometer title_status transmission  ...       size   type  \
# 666     31213 miles      rebuilt    automatic  ...   mid-size  sedan
# 700     27751 miles        clean    automatic  ...   mid-size  sedan
# 724    125468 miles        clean    automatic  ...   mid-size    van
# 733     31213 miles      rebuilt    automatic  ...   mid-size  sedan
# 743     22755 miles        clean    automatic  ...   mid-size  sedan
# ...             ...          ...          ...  ...        ...    ...
# 57564   21132 miles        clean    automatic  ...  full-size    SUV
# 57654   24776 miles        clean    automatic  ...  full-size    SUV
# 57686   38101 miles        clean    automatic  ...  full-size  sedan
# 57967   21404 miles      rebuilt    automatic  ...    compact  sedan
# 57977   30802 miles      rebuilt    automatic  ...   mid-size    SUV
#
#       paint_color state        lat        long  years  odometers      Made  \
# 666         black    ak  61.217776 -149.966984   2018      31213  Japanese
# 700          grey    ak  61.166252 -149.857916   2018      27751  Japanese
# 724          grey    ak  61.166683 -149.868236   2018     125468  American
# 733         black    ak  61.217776 -149.966984   2018      31213  Japanese
# 743          blue    ak  61.166353 -149.847206   2018      22755  Japanese
# ...           ...   ...        ...         ...    ...        ...       ...
# 57564        grey    wi  42.954900  -87.944700   2018      21132  American
# 57654         red    wi  42.975100  -87.894700   2018      24776  American
# 57686         red    wi  42.995900  -87.994400   2018      38101  American
# 57967        grey    wi  44.408744  -89.881210   2018      21404  Japanese
# 57977        grey    wi  44.388100  -89.922800   2018      30802  American
#
#                                              car_details
# 666    Japanese subaru legacy sedan 4 cylinders 2018 ...
# 700    Japanese nissan versa sv sedan 4 cylinders 201...
# 724    American chrysler pacifica van 6 cylinders 201...
# 733    Japanese subaru legacy sedan 4 cylinders 2018 ...
# 743    Japanese nissan sentra s sedan 4 cylinders 201...
# ...                                                  ...
# 57564  American chevrolet equinox SUV 4 cylinders 201...
# 57654  American chevrolet equinox SUV 4 cylinders 201...
# 57686  American ford fusion se sedan 4 cylinders 2018...
# 57967  Japanese nissan sentra sedan 4 cylinders 2018 ...
# 57977  American chevrolet equinox SUV 4 cylinders 201...
#
# [283 rows x 21 columns]
#        price     year manufacturer    model  condition    cylinders fuel  \
# 733    16500  2018 AD       subaru   legacy  excellent  4 cylinders  gas
# 27494  15995  2018 AD       subaru   legacy  excellent  4 cylinders  gas
# 47299  14995  2018 AD       subaru   legacy  excellent  4 cylinders  gas
# 53500  16995  2018 AD       subaru  impreza  excellent  4 cylinders  gas
# 53263  16995  2018 AD       subaru  impreza  excellent  4 cylinders  gas
# 53608  16995  2018 AD       subaru  impreza  excellent  4 cylinders  gas
#
#           odometer title_status transmission  ...      size   type  \
# 733    31213 miles      rebuilt    automatic  ...  mid-size  sedan
# 27494  94000 miles        clean    automatic  ...  mid-size  sedan
# 47299  80076 miles        clean    automatic  ...  mid-size  sedan
# 53500  32363 miles        clean    automatic  ...  mid-size  sedan
# 53263  32363 miles        clean    automatic  ...  mid-size  sedan
# 53608  32363 miles        clean    automatic  ...  mid-size  sedan
#
#       paint_color state        lat        long  years  odometers      Made  \
# 733         black    ak  61.217776 -149.966984   2018      31213  Japanese
# 27494        grey    mi  43.425965  -85.472989   2018      94000  Japanese
# 47299       white    pa  39.970698  -76.705788   2018      80076  Japanese
# 53500       black    vt  44.194500  -72.493600   2018      32363  Japanese
# 53263       black    vt  44.194500  -72.493600   2018      32363  Japanese
# 53608       black    vt  44.194500  -72.493600   2018      32363  Japanese
#
#                                              car_details
# 733    Japanese subaru legacy sedan 4 cylinders 2018 ...
# 27494  Japanese subaru legacy sedan 4 cylinders 2018 ...
# 47299  Japanese subaru legacy sedan 4 cylinders 2018 ...
# 53500  Japanese subaru impreza sedan 4 cylinders 2018...
# 53263  Japanese subaru impreza sedan 4 cylinders 2018...
# 53608  Japanese subaru impreza sedan 4 cylinders 2018...
#
# [6 rows x 21 columns]
